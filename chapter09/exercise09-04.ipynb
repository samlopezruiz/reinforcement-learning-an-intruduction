# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from chapter09.plot import plot_results, plot_learning
from chapter09.maze import ShortcutMazeEnv
from chapter09.dyna import dyna_q

import gymnasium as gym
import numpy as np

# %%
env = gym.make('ShortcutMaze-v0')
env.seed(5); np.random.seed(5)

params = dict(n_episodes=400,
              n_planning_steps=20,
              alpha=0.5,
              gamma=0.95,
              epsilon=0.2,
              kappa=0.0001)

Q_plus, model_plus, history_plus = dyna_q(env,**params, plus=True)
Q, model, history = dyna_q(env,**params, plus=False)

plot_learning([history, history_plus], ['dyna-Q', 'dyna-Q+'])
# Out:
# ...
# 100%|██████████| 400/400 [00:04<00:00, 94.80it/s]

# %%
plot_results(env, Q, 'dyna-Q')

# %%
plot_results(env, Q_plus, 'dyna-Q+')
